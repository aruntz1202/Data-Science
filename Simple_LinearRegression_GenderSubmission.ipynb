# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
ds=pd.read_csv(r"C:\Users\arunf\OneDrive\Documents\Data Science\Machine Learning\DataSet\gender_submission (1).csv")

# %%
ds
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
ds.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
ds.columns=['PassengerId','Survived']
ds.head(10)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
# 5          897         0
# 6          898         1
# 7          899         0
# 8          900         1
# 9          901         0

# %%
plt.scatter(x=ds['PassengerId'],y=ds['Survived'])
plt.show()

# %%
x=ds[['PassengerId']]
y=ds[['Survived']]

# %%
x
# Out:
#      PassengerId
# 0            892
# 1            893
# 2            894
# 3            895
# 4            896
# ..           ...
# 413         1305
# 414         1306
# 415         1307
# 416         1308
# 417         1309
#
# [418 rows x 1 columns]

# %%
trainx,testx,trainy,testy=train_test_split(x,y,test_size=0.2)

# %%
trainx
# Out:
#      PassengerId
# 201         1093
# 34           926
# 411         1303
# 6            898
# 99           991
# ..           ...
# 51           943
# 19           911
# 380         1272
# 348         1240
# 343         1235
#
# [334 rows x 1 columns]

# %%
trainy
# Out:
#      Survived
# 201         0
# 34          0
# 411         1
# 6           1
# 99          0
# ..        ...
# 51          0
# 19          1
# 380         0
# 348         0
# 343         1
#
# [334 rows x 1 columns]

# %%
lr=LinearRegression()

# %%
pred=lr.fit(trainx,trainy).predict(testx)

# %%
pred
# Out:
# array([[0.35367658],
#        [0.36728371],
#        [0.33135478],
#        [0.39098151],
#        [0.39021707],
#        [0.33456545],
#        [0.38501884],
#        [0.37599839],
#        [0.37660994],
#        [0.37339927],
#        [0.38440728],
#        [0.3548997 ],
#        [0.38410151],
#        [0.33838768],
#        [0.35688725],
#        [0.35016014],
#        [0.39067573],
#        [0.38731218],
#        [0.36239126],
#        [0.35382947],
#        [0.38624195],
#        [0.3856304 ],
#        [0.34526769],
#        [0.33487123],
#        [0.38257261],
#        [0.39159307],
#        [0.37278772],
#        [0.34587924],
#        [0.36055659],
#        [0.37095305],
#        [0.38593617],
#        [0.39495663],
#        [0.3938864 ],
#        [0.35337081],
#        [0.3674366 ],
#        [0.37141171],
#        [0.34832547],
#        [0.33471834],
#        [0.37538683],
#        [0.33548279],
#        [0.37691572],
#        [0.35107747],
#        [0.34358591],
# ...

# %%
print(mean_squared_error(pred,testy))
# Out:
# 0.233840063845162
